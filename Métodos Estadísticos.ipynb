# %% [markdown]
# # Métodos de Análisis Estadístico
# *Profesor: Luis Sierra*
# *Curso: Estadística Aplicada*

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import statsmodels.api as sm

# %%
data = np.random.normal(50, 10, 1000)  # Datos normales
print(f"Media: {np.mean(data):.2f}, Mediana: {np.median(data):.2f}")
print(f"Desviación estándar: {np.std(data):.2f}")

# Histograma
plt.hist(data, bins=30, edgecolor='black')
plt.title("Distribución de Datos")
plt.show()
# Out:
# Media: 50.26, Mediana: 49.85
# Desviación estándar: 9.99

# %%
ci = stats.norm.interval(0.95, loc=np.mean(data), scale=stats.sem(data))
print("IC 95%:", ci)
# Out:
# IC 95%: (49.64503738943009, 50.88437001092794)

# %%
sample1 = np.random.normal(50, 10, 100)
sample2 = np.random.normal(55, 10, 100)
t_stat, p_val = stats.ttest_ind(sample1, sample2)
print(f"p-valor: {p_val:.4f}")  # Rechazar H0 si p < 0.05
# Out:
# p-valor: 0.0000
